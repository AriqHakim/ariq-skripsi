# %%
import tensorflow
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet50 import  preprocess_input
# Out:
# 2024-06-03 13:21:19.159111: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-03 13:21:19.191031: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-03 13:21:19.191072: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-03 13:21:19.191967: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-03 13:21:19.196725: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-03 13:21:20.196068: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
src_path_train = "./Data_4_Subclass_cancer/train/"
src_path_valid = "./Data_4_Subclass_cancer/valid/"
src_path_test = "./Data_4_Subclass_cancer/test/"

scale=1
rotation=20
zoom=0.25
width_shift=0.25
height_shift=0.25
shear=0.25

train_datagen = ImageDataGenerator(
        preprocessing_function=preprocess_input,
        dtype='float32',
        rescale=scale,
        rotation_range=rotation,
        # zoom_range=zoom,
        width_shift_range=width_shift,
        height_shift_range=width_shift,
        shear_range=shear,
        horizontal_flip=True)

valid_datagen = ImageDataGenerator(
        preprocessing_function=preprocess_input,    
        dtype='float32',
        rescale=scale,) 

test_datagen = ImageDataGenerator(
        preprocessing_function=preprocess_input,
        dtype='float32',
        rescale=scale,)

# %%
BATCH_SIZE = 32
train_generator = train_datagen.flow_from_directory(
    directory=src_path_train,
    target_size=(224, 224),
    color_mode="rgb",
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    subset='training',
    shuffle=True,
    seed=42
)

valid_generator = valid_datagen.flow_from_directory(
    directory=src_path_valid,
    target_size=(224, 224),
    color_mode="rgb",
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=True,
    seed=42
)

test_generator = test_datagen.flow_from_directory(
    directory=src_path_test,
    target_size=(224, 224),
    color_mode="rgb",
    batch_size=1,
    class_mode='categorical',
    shuffle=False,
    seed=42
)
# Out:
# Found 613 images belonging to 4 classes.
# Found 72 images belonging to 4 classes.
# Found 315 images belonging to 4 classes.

# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, BatchNormalization, Dropout

# %%
NUM_CLASSES = 4

CHANNELS = 3

IMAGE_RESIZE = 224
RESNET50_POOLING_AVERAGE = 'avg'
HIDDEN_LAYER_ACTIVATION = 'relu'
DENSE_LAYER_ACTIVATION = 'softmax'
OBJECTIVE_FUNCTION = 'categorical_crossentropy'

LOSS_METRICS = ['accuracy']

NUM_EPOCHS = 50
EARLY_STOP_PATIENCE = 10

BATCH_SIZE_TESTING = 1
STEPS_PER_EPOCH_TRAINING = int(train_generator.n / BATCH_SIZE) + 1
STEPS_PER_EPOCH_VALIDATION = int(valid_generator.n / BATCH_SIZE) + 1

# %%
model = Sequential()

model.add(ResNet50(include_top = False, pooling = RESNET50_POOLING_AVERAGE, weights = 'imagenet'))
model.add(Flatten())
model.add(BatchNormalization())


# 2nd layer as Dense for 2-class classification, i.e., dog or cat using SoftMax activation
# model.add(Dense(512, activation = HIDDEN_LAYER_ACTIVATION))
# model.add(Dense(256, activation = HIDDEN_LAYER_ACTIVATION))
model.add(Dense(128, activation = HIDDEN_LAYER_ACTIVATION))
# model.add(Dropout(0.5))
model.add(Dense(NUM_CLASSES, activation = DENSE_LAYER_ACTIVATION))
# Say not to train first layer (ResNet) model as it is already trained
model.layers[0].trainable = False

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  flatten_5 (Flatten)         (None, 2048)              0
#
#  batch_normalization_5 (Bat  (None, 2048)              8192
#  chNormalization)
#
#  dense_6 (Dense)             (None, 128)               262272
#
#  dense_7 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 23858692 (91.01 MB)
# Trainable params: 266884 (1.02 MB)
# Non-trainable params: 23591808 (90.00 MB)
# _________________________________________________________________

# %%
from tensorflow.keras import optimizers

sgd = optimizers.SGD(learning_rate = 0.01, momentum = 0.9, nesterov = True)
model.compile(optimizer = sgd, loss = OBJECTIVE_FUNCTION, metrics = LOSS_METRICS)

# %%
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint

cb_early_stopper = EarlyStopping(monitor = 'val_loss', patience = EARLY_STOP_PATIENCE)
cb_checkpointer = ModelCheckpoint(filepath = './models/best.hdf5', monitor = 'val_loss', save_best_only = True, mode = 'auto')

# %%
fit_history = model.fit(
        train_generator,
        steps_per_epoch=STEPS_PER_EPOCH_TRAINING,
        epochs = NUM_EPOCHS,
        validation_data=valid_generator,
        validation_steps=STEPS_PER_EPOCH_VALIDATION,
        callbacks=[
            # cb_early_stopper, 
            cb_checkpointer]
)
# Out:
# Epoch 1/50
# 20/20 [==============================] - 9s 342ms/step - loss: 1.0077 - accuracy: 0.5873 - val_loss: 1.2749 - val_accuracy: 0.5139
# Epoch 2/50
# 20/20 [==============================] - 6s 284ms/step - loss: 0.5866 - accuracy: 0.7781 - val_loss: 1.0895 - val_accuracy: 0.5833
# Epoch 3/50
# 20/20 [==============================] - 6s 288ms/step - loss: 0.4310 - accuracy: 0.8206 - val_loss: 0.8056 - val_accuracy: 0.6389
# Epoch 4/50
# 20/20 [==============================] - 6s 302ms/step - loss: 0.3466 - accuracy: 0.8728 - val_loss: 0.7053 - val_accuracy: 0.6806
# Epoch 5/50
# 20/20 [==============================] - 6s 280ms/step - loss: 0.3350 - accuracy: 0.8662 - val_loss: 0.6730 - val_accuracy: 0.8056
# Epoch 6/50
# 20/20 [==============================] - 6s 280ms/step - loss: 0.2804 - accuracy: 0.8907 - val_loss: 0.8014 - val_accuracy: 0.6806
# Epoch 7/50
# 20/20 [==============================] - 6s 288ms/step - loss: 0.2644 - accuracy: 0.9135 - val_loss: 0.6539 - val_accuracy: 0.8333
# Epoch 8/50
# 20/20 [==============================] - 6s 273ms/step - loss: 0.2123 - accuracy: 0.9184 - val_loss: 0.8649 - val_accuracy: 0.7083
# Epoch 9/50
# 20/20 [==============================] - 6s 309ms/step - loss: 0.2310 - accuracy: 0.9103 - val_loss: 0.6101 - val_accuracy: 0.8194
# Epoch 10/50
# 20/20 [==============================] - 11s 548ms/step - loss: 0.2114 - accuracy: 0.9233 - val_loss: 1.1383 - val_accuracy: 0.6944
# Epoch 11/50
# 20/20 [==============================] - 8s 406ms/step - loss: 0.2133 - accuracy: 0.9266 - val_loss: 0.7565 - val_accuracy: 0.7917
# Epoch 12/50
# 20/20 [==============================] - 6s 278ms/step - loss: 0.1871 - accuracy: 0.9217 - val_loss: 0.6167 - val_accuracy: 0.8194
# Epoch 13/50
# 20/20 [==============================] - 6s 284ms/step - loss: 0.1990 - accuracy: 0.9331 - val_loss: 0.5463 - val_accuracy: 0.9028
# Epoch 14/50
# 20/20 [==============================] - 6s 280ms/step - loss: 0.1772 - accuracy: 0.9396 - val_loss: 0.6425 - val_accuracy: 0.8611
# Epoch 15/50
# 20/20 [==============================] - 6s 288ms/step - loss: 0.1225 - accuracy: 0.9445 - val_loss: 0.7867 - val_accuracy: 0.8194
# Epoch 16/50
# 20/20 [==============================] - 6s 270ms/step - loss: 0.1360 - accuracy: 0.9527 - val_loss: 0.7023 - val_accuracy: 0.8889
# Epoch 17/50
# 20/20 [==============================] - 6s 286ms/step - loss: 0.0977 - accuracy: 0.9625 - val_loss: 0.6936 - val_accuracy: 0.8472
# Epoch 18/50
# 20/20 [==============================] - 6s 271ms/step - loss: 0.1813 - accuracy: 0.9429 - val_loss: 0.9167 - val_accuracy: 0.8333
# Epoch 19/50
# 20/20 [==============================] - 6s 274ms/step - loss: 0.2553 - accuracy: 0.9054 - val_loss: 0.9925 - val_accuracy: 0.8333
# Epoch 20/50
# 20/20 [==============================] - 5s 266ms/step - loss: 0.1668 - accuracy: 0.9494 - val_loss: 0.8166 - val_accuracy: 0.8611
# Epoch 21/50
# 20/20 [==============================] - 6s 293ms/step - loss: 0.1352 - accuracy: 0.9625 - val_loss: 0.9303 - val_accuracy: 0.8194
# Epoch 22/50
# 20/20 [==============================] - 6s 288ms/step - loss: 0.2183 - accuracy: 0.9315 - val_loss: 0.9598 - val_accuracy: 0.8611
# Epoch 23/50
# 20/20 [==============================] - 5s 266ms/step - loss: 0.1584 - accuracy: 0.9527 - val_loss: 0.9522 - val_accuracy: 0.8472
# Epoch 24/50
# 20/20 [==============================] - 5s 267ms/step - loss: 0.2030 - accuracy: 0.9233 - val_loss: 1.2629 - val_accuracy: 0.7639
# Epoch 25/50
# 20/20 [==============================] - 5s 260ms/step - loss: 0.2039 - accuracy: 0.9299 - val_loss: 1.0097 - val_accuracy: 0.8333
# Epoch 26/50
# 20/20 [==============================] - 5s 259ms/step - loss: 0.1702 - accuracy: 0.9445 - val_loss: 0.8439 - val_accuracy: 0.8472
# Epoch 27/50
# 20/20 [==============================] - 5s 268ms/step - loss: 0.1277 - accuracy: 0.9478 - val_loss: 0.9012 - val_accuracy: 0.8333
# Epoch 28/50
# 20/20 [==============================] - 5s 261ms/step - loss: 0.1156 - accuracy: 0.9641 - val_loss: 1.0215 - val_accuracy: 0.8750
# Epoch 29/50
# 20/20 [==============================] - 5s 266ms/step - loss: 0.0925 - accuracy: 0.9543 - val_loss: 1.0093 - val_accuracy: 0.8611
# Epoch 30/50
# 20/20 [==============================] - 5s 268ms/step - loss: 0.0873 - accuracy: 0.9657 - val_loss: 0.9208 - val_accuracy: 0.8611
# Epoch 31/50
# 20/20 [==============================] - 5s 266ms/step - loss: 0.1772 - accuracy: 0.9445 - val_loss: 1.1499 - val_accuracy: 0.8472
# Epoch 32/50
# 20/20 [==============================] - 5s 267ms/step - loss: 0.1078 - accuracy: 0.9641 - val_loss: 1.0073 - val_accuracy: 0.8889
# Epoch 33/50
# 20/20 [==============================] - 6s 276ms/step - loss: 0.1175 - accuracy: 0.9657 - val_loss: 1.0981 - val_accuracy: 0.8611
# Epoch 34/50
# 20/20 [==============================] - 5s 263ms/step - loss: 0.1249 - accuracy: 0.9592 - val_loss: 1.2181 - val_accuracy: 0.8472
# Epoch 35/50
# 20/20 [==============================] - 5s 278ms/step - loss: 0.1295 - accuracy: 0.9560 - val_loss: 1.0561 - val_accuracy: 0.8611
# Epoch 36/50
# 20/20 [==============================] - 5s 266ms/step - loss: 0.1622 - accuracy: 0.9608 - val_loss: 1.0453 - val_accuracy: 0.8333
# Epoch 37/50
# 20/20 [==============================] - 6s 269ms/step - loss: 0.1307 - accuracy: 0.9641 - val_loss: 0.9046 - val_accuracy: 0.8750
# Epoch 38/50
# 20/20 [==============================] - 5s 269ms/step - loss: 0.0876 - accuracy: 0.9641 - val_loss: 0.9144 - val_accuracy: 0.8472
# Epoch 39/50
# 20/20 [==============================] - 5s 264ms/step - loss: 0.0876 - accuracy: 0.9608 - val_loss: 0.8468 - val_accuracy: 0.8889
# Epoch 40/50
# 20/20 [==============================] - 5s 264ms/step - loss: 0.0891 - accuracy: 0.9739 - val_loss: 0.8627 - val_accuracy: 0.8889
# Epoch 41/50
# 20/20 [==============================] - 5s 264ms/step - loss: 0.0613 - accuracy: 0.9772 - val_loss: 0.9439 - val_accuracy: 0.8889
# Epoch 42/50
# 20/20 [==============================] - 6s 276ms/step - loss: 0.0683 - accuracy: 0.9706 - val_loss: 1.0498 - val_accuracy: 0.8750
# Epoch 43/50
# 20/20 [==============================] - 5s 262ms/step - loss: 0.0993 - accuracy: 0.9625 - val_loss: 1.2775 - val_accuracy: 0.8889
# Epoch 44/50
# 20/20 [==============================] - 5s 270ms/step - loss: 0.0837 - accuracy: 0.9755 - val_loss: 1.0191 - val_accuracy: 0.8889
# Epoch 45/50
# 20/20 [==============================] - 6s 282ms/step - loss: 0.0360 - accuracy: 0.9853 - val_loss: 1.0508 - val_accuracy: 0.8889
# Epoch 46/50
# 20/20 [==============================] - 5s 269ms/step - loss: 0.0619 - accuracy: 0.9788 - val_loss: 1.1257 - val_accuracy: 0.8611
# Epoch 47/50
# 20/20 [==============================] - 5s 265ms/step - loss: 0.0736 - accuracy: 0.9723 - val_loss: 0.9237 - val_accuracy: 0.8750
# Epoch 48/50
# 20/20 [==============================] - 5s 257ms/step - loss: 0.0819 - accuracy: 0.9739 - val_loss: 0.8493 - val_accuracy: 0.8889
# Epoch 49/50
# 20/20 [==============================] - 6s 272ms/step - loss: 0.0500 - accuracy: 0.9821 - val_loss: 0.9619 - val_accuracy: 0.8472
# Epoch 50/50
# 20/20 [==============================] - 5s 263ms/step - loss: 0.0367 - accuracy: 0.9902 - val_loss: 0.8089 - val_accuracy: 0.9028

# %%
import matplotlib.pyplot as plt
plt.plot(fit_history.history['accuracy'], label = 'train',)
plt.plot(fit_history.history['val_accuracy'], label = 'val')

plt.legend(loc = 'right')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.show()

# %%
plt.plot(fit_history.history['loss'], label = 'train',)
plt.plot(fit_history.history['val_loss'], label = 'val')

plt.legend(loc = 'right')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.show()

# %%
# model.load_weights(filepath='./models/best.hdf5')
model.evaluate(test_generator)
# Out:
# 315/315 [==============================] - 6s 17ms/step - loss: 0.7518 - accuracy: 0.8127
# [0.7518110275268555, 0.8126984238624573]
