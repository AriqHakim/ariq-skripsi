# %%
import tensorflow
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet50 import  preprocess_input
# Out:
# 2024-06-03 13:21:18.039985: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-03 13:21:18.619645: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-03 13:21:18.619686: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-03 13:21:18.726958: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-03 13:21:18.973237: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-03 13:21:20.196064: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
src_path_train = "./Data_IQ_OTHNCCD/train/"
src_path_valid = "./Data_IQ_OTHNCCD/valid/"
src_path_test = "./Data_IQ_OTHNCCD/test/"

scale=1
rotation=20
zoom=0.25
width_shift=0.25
height_shift=0.25
shear=0.25

train_datagen = ImageDataGenerator(
        preprocessing_function=preprocess_input,
        dtype='float32',
        rescale=scale,
        rotation_range=rotation,
        # zoom_range=zoom,
        width_shift_range=width_shift,
        height_shift_range=width_shift,
        shear_range=shear,
        horizontal_flip=True)

valid_datagen = ImageDataGenerator(
        preprocessing_function=preprocess_input,    
        dtype='float32',
        rescale=scale,) 

test_datagen = ImageDataGenerator(
        preprocessing_function=preprocess_input,
        dtype='float32',
        rescale=scale,)

# %%
BATCH_SIZE = 32
train_generator = train_datagen.flow_from_directory(
    directory=src_path_train,
    target_size=(224, 224),
    color_mode="rgb",
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    subset='training',
    shuffle=True,
    seed=42
)

valid_generator = valid_datagen.flow_from_directory(
    directory=src_path_valid,
    target_size=(224, 224),
    color_mode="rgb",
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=True,
    seed=42
)

test_generator = test_datagen.flow_from_directory(
    directory=src_path_test,
    target_size=(224, 224),
    color_mode="rgb",
    batch_size=1,
    class_mode='categorical',
    shuffle=False,
    seed=42
)
# Out:
# Found 763 images belonging to 3 classes.
# Found 218 images belonging to 3 classes.
# Found 116 images belonging to 3 classes.

# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, BatchNormalization, Dropout

# %%
NUM_CLASSES = 3

CHANNELS = 3

IMAGE_RESIZE = 224
RESNET50_POOLING_AVERAGE = 'avg'
HIDDEN_LAYER_ACTIVATION = 'relu'
DENSE_LAYER_ACTIVATION = 'softmax'
OBJECTIVE_FUNCTION = 'categorical_crossentropy'

LOSS_METRICS = ['accuracy']

NUM_EPOCHS = 50
EARLY_STOP_PATIENCE = 10

BATCH_SIZE_TESTING = 1

STEPS_PER_EPOCH_TRAINING = int(train_generator.n / BATCH_SIZE) + 1
STEPS_PER_EPOCH_VALIDATION = int(valid_generator.n / BATCH_SIZE) + 1

# %%
model = Sequential()

model.add(ResNet50(include_top = False, pooling = RESNET50_POOLING_AVERAGE, weights = 'imagenet'))
model.add(Flatten())
model.add(BatchNormalization())


# 2nd layer as Dense for 2-class classification, i.e., dog or cat using SoftMax activation
# model.add(Dense(512, activation = HIDDEN_LAYER_ACTIVATION))
# model.add(Dense(256, activation = HIDDEN_LAYER_ACTIVATION))
model.add(Dense(128, activation = HIDDEN_LAYER_ACTIVATION))
# model.add(Dropout(0.5))
model.add(Dense(NUM_CLASSES, activation = DENSE_LAYER_ACTIVATION))
# Say not to train first layer (ResNet) model as it is already trained
model.layers[0].trainable = False

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  flatten_9 (Flatten)         (None, 2048)              0
#
#  batch_normalization_9 (Bat  (None, 2048)              8192
#  chNormalization)
#
#  dense_10 (Dense)            (None, 128)               262272
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_11 (Dense)            (None, 3)                 387
#
# =================================================================
# Total params: 23858563 (91.01 MB)
# Trainable params: 266755 (1.02 MB)
# Non-trainable params: 23591808 (90.00 MB)
# _________________________________________________________________

# %%
from tensorflow.keras import optimizers

sgd = optimizers.SGD(learning_rate = 0.01, momentum = 0.9, nesterov = True)
model.compile(optimizer = sgd, loss = OBJECTIVE_FUNCTION, metrics = LOSS_METRICS)

# %%
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint

cb_early_stopper = EarlyStopping(monitor = 'val_loss', patience = EARLY_STOP_PATIENCE)
cb_checkpointer = ModelCheckpoint(filepath = './models/IQ_OTH/model.hdf5', monitor = 'val_loss', save_best_only = False, mode = 'auto')

# %%
fit_history = model.fit(
        train_generator,
        steps_per_epoch=STEPS_PER_EPOCH_TRAINING,
        epochs = NUM_EPOCHS,
        validation_data=valid_generator,
        validation_steps=STEPS_PER_EPOCH_VALIDATION,
        callbacks=[
            # cb_early_stopper, 
            cb_checkpointer]
)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 10s 315ms/step - loss: 0.4614 - accuracy: 0.8060 - val_loss: 1.0692 - val_accuracy: 0.7661
# Epoch 2/50
# 24/24 [==============================] - 6s 267ms/step - loss: 0.2378 - accuracy: 0.9043 - val_loss: 1.0874 - val_accuracy: 0.7385
# Epoch 3/50
# 24/24 [==============================] - 7s 282ms/step - loss: 0.1783 - accuracy: 0.9227 - val_loss: 1.0109 - val_accuracy: 0.7018
# Epoch 4/50
# 24/24 [==============================] - 7s 278ms/step - loss: 0.1474 - accuracy: 0.9384 - val_loss: 1.0318 - val_accuracy: 0.7064
# Epoch 5/50
# 24/24 [==============================] - 6s 266ms/step - loss: 0.1244 - accuracy: 0.9463 - val_loss: 1.1206 - val_accuracy: 0.6697
# Epoch 6/50
# 24/24 [==============================] - 7s 269ms/step - loss: 0.1038 - accuracy: 0.9594 - val_loss: 1.1928 - val_accuracy: 0.6560
# Epoch 7/50
# 24/24 [==============================] - 7s 272ms/step - loss: 0.0955 - accuracy: 0.9738 - val_loss: 1.3354 - val_accuracy: 0.6835
# Epoch 8/50
# 24/24 [==============================] - 7s 271ms/step - loss: 0.0855 - accuracy: 0.9620 - val_loss: 1.4015 - val_accuracy: 0.7248
# Epoch 9/50
# 24/24 [==============================] - 7s 268ms/step - loss: 0.0767 - accuracy: 0.9712 - val_loss: 1.4074 - val_accuracy: 0.6697
# Epoch 10/50
# 24/24 [==============================] - 8s 313ms/step - loss: 0.0744 - accuracy: 0.9751 - val_loss: 1.4586 - val_accuracy: 0.7110
# Epoch 11/50
# 24/24 [==============================] - 8s 324ms/step - loss: 0.0791 - accuracy: 0.9659 - val_loss: 1.6610 - val_accuracy: 0.7018
# Epoch 12/50
# 24/24 [==============================] - 8s 344ms/step - loss: 0.0876 - accuracy: 0.9699 - val_loss: 1.9433 - val_accuracy: 0.7202
# Epoch 13/50
# 24/24 [==============================] - 8s 310ms/step - loss: 0.0538 - accuracy: 0.9856 - val_loss: 1.6555 - val_accuracy: 0.6697
# Epoch 14/50
# 24/24 [==============================] - 7s 299ms/step - loss: 0.0616 - accuracy: 0.9764 - val_loss: 1.8696 - val_accuracy: 0.6743
# Epoch 15/50
# 24/24 [==============================] - 7s 278ms/step - loss: 0.0680 - accuracy: 0.9777 - val_loss: 2.0035 - val_accuracy: 0.7431
# Epoch 16/50
# 24/24 [==============================] - 7s 287ms/step - loss: 0.0607 - accuracy: 0.9777 - val_loss: 1.9438 - val_accuracy: 0.6789
# Epoch 17/50
# 24/24 [==============================] - 7s 269ms/step - loss: 0.0474 - accuracy: 0.9830 - val_loss: 1.9139 - val_accuracy: 0.6651
# Epoch 18/50
# 24/24 [==============================] - 6s 266ms/step - loss: 0.0336 - accuracy: 0.9882 - val_loss: 2.1520 - val_accuracy: 0.6743
# Epoch 19/50
# 24/24 [==============================] - 7s 308ms/step - loss: 0.0592 - accuracy: 0.9777 - val_loss: 1.9819 - val_accuracy: 0.6284
# Epoch 20/50
# 24/24 [==============================] - 9s 384ms/step - loss: 0.0523 - accuracy: 0.9830 - val_loss: 2.1051 - val_accuracy: 0.6239
# Epoch 21/50
# 24/24 [==============================] - 7s 300ms/step - loss: 0.0445 - accuracy: 0.9790 - val_loss: 2.1123 - val_accuracy: 0.6284
# Epoch 22/50
# 24/24 [==============================] - 7s 285ms/step - loss: 0.0702 - accuracy: 0.9738 - val_loss: 1.8942 - val_accuracy: 0.6835
# Epoch 23/50
# 24/24 [==============================] - 7s 281ms/step - loss: 0.0441 - accuracy: 0.9777 - val_loss: 2.0933 - val_accuracy: 0.6606
# Epoch 24/50
# 24/24 [==============================] - 7s 277ms/step - loss: 0.0347 - accuracy: 0.9882 - val_loss: 2.1958 - val_accuracy: 0.6972
# Epoch 25/50
# 24/24 [==============================] - 7s 275ms/step - loss: 0.0424 - accuracy: 0.9817 - val_loss: 2.1720 - val_accuracy: 0.7156
# Epoch 26/50
# 24/24 [==============================] - 7s 282ms/step - loss: 0.0483 - accuracy: 0.9869 - val_loss: 2.1944 - val_accuracy: 0.6422
# Epoch 27/50
# 24/24 [==============================] - 7s 293ms/step - loss: 0.0441 - accuracy: 0.9869 - val_loss: 2.3007 - val_accuracy: 0.7018
# Epoch 28/50
# 24/24 [==============================] - 7s 279ms/step - loss: 0.0320 - accuracy: 0.9895 - val_loss: 2.4332 - val_accuracy: 0.6927
# Epoch 29/50
# 24/24 [==============================] - 7s 282ms/step - loss: 0.0284 - accuracy: 0.9869 - val_loss: 2.3430 - val_accuracy: 0.6330
# Epoch 30/50
# 24/24 [==============================] - 7s 284ms/step - loss: 0.0314 - accuracy: 0.9882 - val_loss: 2.3279 - val_accuracy: 0.6835
# Epoch 31/50
# 24/24 [==============================] - 7s 284ms/step - loss: 0.0271 - accuracy: 0.9921 - val_loss: 2.4286 - val_accuracy: 0.6284
# Epoch 32/50
# 24/24 [==============================] - 7s 288ms/step - loss: 0.0396 - accuracy: 0.9869 - val_loss: 2.3023 - val_accuracy: 0.6881
# Epoch 33/50
# 24/24 [==============================] - 7s 275ms/step - loss: 0.0258 - accuracy: 0.9921 - val_loss: 2.2475 - val_accuracy: 0.6835
# Epoch 34/50
# 24/24 [==============================] - 7s 283ms/step - loss: 0.0353 - accuracy: 0.9882 - val_loss: 2.0805 - val_accuracy: 0.6743
# Epoch 35/50
# 24/24 [==============================] - 7s 272ms/step - loss: 0.0218 - accuracy: 0.9908 - val_loss: 2.3435 - val_accuracy: 0.6881
# Epoch 36/50
# 24/24 [==============================] - 7s 274ms/step - loss: 0.0345 - accuracy: 0.9882 - val_loss: 2.2385 - val_accuracy: 0.6560
# Epoch 37/50
# 24/24 [==============================] - 7s 274ms/step - loss: 0.0249 - accuracy: 0.9895 - val_loss: 2.1534 - val_accuracy: 0.6697
# Epoch 38/50
# 24/24 [==============================] - 7s 282ms/step - loss: 0.0146 - accuracy: 0.9961 - val_loss: 2.0304 - val_accuracy: 0.6927
# Epoch 39/50
# 24/24 [==============================] - 7s 272ms/step - loss: 0.0269 - accuracy: 0.9948 - val_loss: 2.1538 - val_accuracy: 0.6606
# Epoch 40/50
# 24/24 [==============================] - 7s 269ms/step - loss: 0.0328 - accuracy: 0.9908 - val_loss: 2.2483 - val_accuracy: 0.6606
# Epoch 41/50
# 24/24 [==============================] - 7s 268ms/step - loss: 0.0184 - accuracy: 0.9921 - val_loss: 2.4305 - val_accuracy: 0.7385
# Epoch 42/50
# 24/24 [==============================] - 7s 266ms/step - loss: 0.0248 - accuracy: 0.9921 - val_loss: 2.3334 - val_accuracy: 0.7064
# Epoch 43/50
# 24/24 [==============================] - 7s 271ms/step - loss: 0.0212 - accuracy: 0.9934 - val_loss: 2.1815 - val_accuracy: 0.7064
# Epoch 44/50
# 24/24 [==============================] - 6s 264ms/step - loss: 0.0204 - accuracy: 0.9921 - val_loss: 2.2456 - val_accuracy: 0.7156
# Epoch 45/50
# 24/24 [==============================] - 7s 279ms/step - loss: 0.0215 - accuracy: 0.9961 - val_loss: 2.1710 - val_accuracy: 0.7064
# Epoch 46/50
# 24/24 [==============================] - 7s 287ms/step - loss: 0.0112 - accuracy: 0.9974 - val_loss: 2.1823 - val_accuracy: 0.7018
# Epoch 47/50
# 24/24 [==============================] - 7s 278ms/step - loss: 0.0264 - accuracy: 0.9882 - val_loss: 2.2985 - val_accuracy: 0.7064
# Epoch 48/50
# 24/24 [==============================] - 7s 290ms/step - loss: 0.0309 - accuracy: 0.9843 - val_loss: 2.4475 - val_accuracy: 0.6651
# Epoch 49/50
# 24/24 [==============================] - 7s 271ms/step - loss: 0.0247 - accuracy: 0.9882 - val_loss: 2.3515 - val_accuracy: 0.6606
# Epoch 50/50
# 24/24 [==============================] - 7s 286ms/step - loss: 0.0158 - accuracy: 0.9948 - val_loss: 2.3010 - val_accuracy: 0.6376

# %%
import matplotlib.pyplot as plt
plt.plot(fit_history.history['accuracy'], label = 'train',)
plt.plot(fit_history.history['val_accuracy'], label = 'val')

plt.legend(loc = 'right')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.show()

# %%
plt.plot(fit_history.history['loss'], label = 'train',)
plt.plot(fit_history.history['val_loss'], label = 'val')

plt.legend(loc = 'right')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.show()

# %%
model.load_weights(filepath='./models/best.hdf5')
model.evaluate(test_generator)
# Out:
# 116/116 [==============================] - 8s 66ms/step - loss: 1.2667 - accuracy: 0.7069
# [1.2666676044464111, 0.7068965435028076]
